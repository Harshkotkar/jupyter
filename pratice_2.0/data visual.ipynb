# %% [markdown]
# # bar graph

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[2,3,4]
y=[20,30,40]

plt.bar(x,y)
plt.show()

# %%
courses = ['Math', 'Physics', 'Chemistry', 'Biology']
values = [35, 42, 28, 30]

plt.bar(courses, values, color='maroon', width=)
plt.xlabel("Y-axix score")
plt.ylabel("X-axis courses")
plt.title("Students enrolled in different courses")

plt.show()
# Out:
#   Cell In[3], line 4
#     plt.bar(courses, values, color='maroon', width=)
#                                                    ^
# SyntaxError: invalid syntax

# %%
df={"bio":35,'physics':30,'chem':25,'english':28,"evs":35}
fields=list(df.keys())
student=list(df.values())
fig=plt.figure(figsize=(10,5))
c=['green','blue','red','yellow']
plt.bar(fields,student,color=c,width=0.5)
plt.xlabel("subject")
plt.ylabel('marks')
plt.title("subject marks")

plt.show()

# %%
df={"bio":35,'physics':30,'chem':25,'english':28,"evs":35}
fields=list(df.keys())
student=list(df.values())
fig=plt.figure(figsize=(10,5))
c=['green','blue','red','yellow']
plt.barh(fields,student,color=c)
plt.xlabel("subject")
plt.ylabel('marks')
plt.title("subject marks")

plt.show()

# %%
df=pd.read_csv(r'C:\Users\HP\Desktop\jupyter\ML(clg)\titanic.csv')
df.head()
data=df[['Name','Fare']]
data.head()
# Out:
#                                                 Name     Fare
# 0                            Braund, Mr. Owen Harris   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                             Heikkinen, Miss. Laina   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                           Allen, Mr. William Henry   8.0500

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    891 non-null    object
#  1   Fare    891 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.0+ KB

# %%
print(data.isnull().sum())
# Out:
# Name    0
# Fare    0
# dtype: int64

# %%
data.describe()
# Out:
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
def short(n):
    return n[:5]+'.' if len(n)>10 else n

data.loc[:,'Short_name']=data['Name'].apply(short)
print(data[['Name','Short_name']].head(10))
# Out:
#                                                 Name Short_name
# 0                            Braund, Mr. Owen Harris     Braun.
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...     Cumin.
# 2                             Heikkinen, Miss. Laina     Heikk.
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)     Futre.
# 4                           Allen, Mr. William Henry     Allen.
# 5                                   Moran, Mr. James     Moran.
# 6                            McCarthy, Mr. Timothy J     McCar.
# 7                     Palsson, Master. Gosta Leonard     Palss.
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     Johns.
# 9                Nasser, Mrs. Nicholas (Adele Achem)     Nasse.
# C:\Users\HP\AppData\Local\Temp\ipykernel_13052\122621327.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data
# Out:
#                                                   Name     Fare Short_name
# 0                              Braund, Mr. Owen Harris   7.2500     Braun.
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833     Cumin.
# 2                               Heikkinen, Miss. Laina   7.9250     Heikk.
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000     Futre.
# 4                             Allen, Mr. William Henry   8.0500     Allen.
# ..                                                 ...      ...        ...
# 886                              Montvila, Rev. Juozas  13.0000     Montv.
# 887                       Graham, Miss. Margaret Edith  30.0000     Graha.
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500     Johns.
# 889                              Behr, Mr. Karl Howell  30.0000     Behr,.
# 890                                Dooley, Mr. Patrick   7.7500     Doole.
#
# [891 rows x 3 columns]

# %%
del data['short_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'short_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 del data['short_name']
#
# ...

# %%
data

# %%
data.head(10)
# Out:
#                                                 Name     Fare Short_name
# 0                            Braund, Mr. Owen Harris   7.2500     Braun.
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833     Cumin.
# 2                             Heikkinen, Miss. Laina   7.9250     Heikk.
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000     Futre.
# 4                           Allen, Mr. William Henry   8.0500     Allen.
# 5                                   Moran, Mr. James   8.4583     Moran.
# 6                            McCarthy, Mr. Timothy J  51.8625     McCar.
# 7                     Palsson, Master. Gosta Leonard  21.0750     Palss.
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  11.1333     Johns.
# 9                Nasser, Mrs. Nicholas (Adele Achem)  30.0708     Nasse.

# %%
name=data['Short_name'].head(10)
fare=data['Fare'].head(10)
fig=plt.figure(figsize=(20,10))
plt.bar(name[0:10],fare[0:10])
plt.xlabel("X-axis Names")
plt.ylabel("Y-axis Ticket fare")
plt.show()

# %%
name=data['Short_name'].tail(10)
fair=data['Fare'].tail(10)
fig=plt.figure(figsize=(20,10))
plt.bar(name,fare)
plt.xlabel("X-axis Name")
plt.ylabel("Y-axis Travel fare")
plt.title("Titanic name and fare")
plt.show()

# %%
data['Short_name'].tail(10)
# Out:
# 881    Marku.
# 882    Dahlb.
# 883    Banfi.
# 884    Suteh.
# 885    Rice,.
# 886    Montv.
# 887    Graha.
# 888    Johns.
# 889    Behr,.
# 890    Doole.
# Name: Short_name, dtype: object

# %%
name=data['Short_name'].head(20)
fare=data['Fare'].head(20)
fig=plt.figure(figsize=(20,10))
plt.barh(name,fare)
plt.title("Titanic name and fare")
plt.xlabel("X-label name")
plt.ylabel("Y-lable")
plt.show()

# %%
x=np.random.randn(1000)

plt.hist(x,10)
plt.xlabel("20 random numbers")
plt.ylabel("100 random numbers")
plt.show()

# %%
data["Fare"].head(10).plot(kind='line',marker="o")
# Out:
# <Axes: >

# %%
data['Fare'].head(10)
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# 5     8.4583
# 6    51.8625
# 7    21.0750
# 8    11.1333
# 9    30.0708
# Name: Fare, dtype: float64

# %%
name=data['Short_name'].head(20)
fare=data['Fare'].head(20)
fig,ax=plt.subplots(figsize=(20,10))
ax.barh(name,fare,color='skyblue')

for s in ['top','bottom','left','right']:
    ax.spines[s].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

ax.xaxis.set_tick_params(pad=5)
ax.yaxis.set_tick_params(pad=10)

ax.grid(visible=True,color='grey',
       linestyle='-.',linewidth=0.5,alpha=0.2)
for i in ax.patches:
    plt.text(i.get_width()+0.2,i.get_y()+0.5, 
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')

ax.set_title('Titanic name and fare',
             loc ='left', )

fig.text(0.9, 0.15," ", fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [10, 20, 15, 25]
plt.bar(categories, values, edgecolor='pink', linewidth=2,color='white')
plt.show()

# %%
#  using these cmd we can save the plt to local file
plt.savefig('fig_name.png') ,.pf,.svg
# Out:
#   Cell In[46], line 2
#     plt.savefig('fig_name.png') ,.pf,.svg
#                                  ^
# SyntaxError: invalid syntax

# %%
#using matplotlib

year=[2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024]#bunny
incomes=[38,46,55,56,46,61,73,49,40,34,84]
income=[33,36,45,56,76,67,87,69,76,72,74]#cassendra

plt.plot(year,incomes,linewidth=0.6)
plt.plot(year,income,linewidth=0.6)

income_ticks = list(range(30, 90, 5))
plt.yticks(income_ticks, [f"{x}k USD" for x in income_ticks])

plt.xlabel("Years")
plt.ylabel(" Income in USD")
plt.legend(['bunny','cassendra'])
plt.xticks(year,rotation=45)
plt.grid(False)
plt.show()

# %%
#using seabon
import seaborn as sns


year = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
b_incomes = [38, 46, 55, 56, 46, 61, 73, 49, 40, 34, 84]
c_incomes = [33, 36, 45, 56, 76, 67, 87, 69, 76, 72, 74]

df = pd.DataFrame({"year": year, "b_income": b_incomes, "c_income": c_incomes})


plt.figure(figsize=(20,10))
sns.lineplot(x='year', y='b_income', data=df, marker='o', label='Bunny Income')
sns.lineplot(x='year', y='c_income', data=df, marker='o', label='Cassendra Income')


plt.title('Income Comparison of Bunny and Cassendra ')
plt.xlabel('Year')
plt.ylabel('Income')
plt.grid(False)
plt.legend(loc="upper left")
plt.xticks(year, rotation=45)
plt.tight_layout()
plt.show()

# %%
x=[1,2,4,3,5,8,6,8]
y=[10,20,30,40,50,60,80,90]
plt.figure(1)
plt.plot(x)

plt.figure(2) #use to plot multiple graphs at a time
plt.scatter(x,y)

plt.figure(3)

plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
#subplots

x=np.arange(50)

fig,axs=plt.subplots(2,2)

axs[0,0].plot(x,np.sin(x))
axs[0,0].set_title("Sine wave")

axs[0,1].plot(x,np.cos(x))
axs[0,1].set_title('Cosine wave')

axs[1,0].plot(x,np.random.random(50))
axs[1,0].set_title("Random values")

axs[1,1].plot(x,np.log(x))
axs[1,1].set_title("Log Function")

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13052\3571230354.py:16: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x,np.log(x))

# %%
ax=plt.axes(projection="3d")
x=np.random.random(100)
y=np.random.random(100)
z=np.random.random(100)
ax.scatter(x,y,z)
ax.set_title("3D")
# Out:
# Text(0.5, 0.92, '3D')

# %%
df=pd.read_csv(r'C:\Users\HP\Desktop\jupyter\ML(clg)\titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.boxplot(data=df,x="Survived",y="Age")
plt.show()

# %%
df.Age[df.Pclass==1].plot(kind="kde")
df.Age[df.Pclass==2].plot(kind="kde")
plt.legend(("1st class",'2nd class'))
plt.show()

# %%
sns.histplot(data=df, x='Age', kde=True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()


# Example using sns.kdeplot()
sns.kdeplot(data=df['Age'], shade=True)
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age Density Plot')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13052\4285864613.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df['Age'], shade=True)
