# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
data=pd.read_csv("C:\\ConsumerComplaint.csv")
data.head()
# Out:
#   Date Received             Product Name                  Sub Product  \
# 0    29-07-2013            Consumer Loan                 Vehicle loan
# 1    29-07-2013  Bank account or service             Checking account
# 2    29-07-2013  Bank account or service             Checking account
# 3    29-07-2013  Bank account or service             Checking account
# 4    29-07-2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub Issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#    Consumer Complaint Narrative  Company Public Response  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# ...

# %%
data.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 0 to 835
# Columns: 18 entries, Date Received to Complaint ID
# dtypes: float64(4), int64(1), object(13)
# memory usage: 117.7+ KB

# %%
data.size
# Out:
# 15048

# %%
data.shape
# Out:
# (836, 18)

# %%
(data.isnull().sum()/data.shape[0])*100
# Out:
# Date Received                     0.000000
# Product Name                      0.000000
# Sub Product                      24.162679
# Issue                             0.000000
# Sub Issue                        73.444976
# Consumer Complaint Narrative    100.000000
# Company Public Response         100.000000
# Company                           0.000000
# State Name                        0.358852
# Zip Code                          0.358852
# Tags                             86.004785
# Consumer Consent Provided       100.000000
# Submitted via                     0.000000
# Date Sent to Company              0.000000
# Company Response to Consumer      0.000000
# Timely Response                   0.000000
# Consumer Disputed                 0.717703
# Complaint ID                      0.000000
# dtype: float64

# %%
(data.isnull().sum().sum()/(data.shape[0]*data.shape[1]))*100
# Out:
# 26.94710260499734

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.isnull())
plt.title("ConsumerComplaints null values")
plt.show()

# %%
data.drop(columns=["Consumer Complaint Narrative","Company Public Response"],inplace=True)

# %%
data.drop(columns=["Consumer Consent Provided","Tags","Sub Issue"],inplace=True)

# %%
data.shape
# Out:
# (836, 13)

# %%
(data.isnull().sum().sum()/(data.shape[0]*data.shape[1]))*100
# Out:
# 1.9690835480309163

# %%
(data.isnull().sum()/data.shape[0])*100
# Out:
# Date Received                    0.000000
# Product Name                     0.000000
# Sub Product                     24.162679
# Issue                            0.000000
# Company                          0.000000
# State Name                       0.358852
# Zip Code                         0.358852
# Submitted via                    0.000000
# Date Sent to Company             0.000000
# Company Response to Consumer     0.000000
# Timely Response                  0.000000
# Consumer Disputed                0.717703
# Complaint ID                     0.000000
# dtype: float64

# %%
data["Sub Product"].unique()
# Out:
# array(['Vehicle loan', 'Checking account', 'Conventional fixed mortgage',
#        'Other (i.e. phone, health club, etc.)', 'I do not know', nan,
#        'Other mortgage', 'Credit card',
#        'Conventional adjustable mortgage (ARM)',
#        'Other bank product/service', 'Non-federal student loan',
#        'FHA mortgage', '(CD) Certificate of deposit',
#        'Home equity loan or line of credit', 'Vehicle lease',
#        'Savings account', 'Federal student loan', 'Mortgage',
#        'Reverse mortgage', 'Auto', 'Installment loan', 'Medical',
#        'VA mortgage', 'Domestic (US) money transfer'], dtype=object)

# %%
data[data["Sub Product"].isna()]
# Out:
#     Date Received      Product Name Sub Product  \
# 8      29-07-2013       Credit card         NaN
# 19     29-07-2013       Credit card         NaN
# 20     29-07-2013  Credit reporting         NaN
# 28     29-07-2013  Credit reporting         NaN
# 37     29-07-2013       Credit card         NaN
# ..            ...               ...         ...
# 815    24-07-2013       Credit card         NaN
# 816    25-07-2013  Credit reporting         NaN
# 818    24-07-2013  Credit reporting         NaN
# 827    01-08-2013  Credit reporting         NaN
# 835    25-07-2013  Credit reporting         NaN
#
#                                         Issue              Company State Name  \
# 8                           Billing statement             Citibank         OH
# 19                       APR or interest rate  Synchrony Financial         WA
# 20   Credit monitoring or identity protection             Experian         CA
# ...

# %% [markdown]
# # fillin the null values  with 4 diffrent methods
#
# 1)with specific value such as "unknown"
#
# 2)with mode of the column
#
# 3)filling the nan with forward fill(copy previous value)
#
# 4)filling the nan with backwardfill(copy next value)

# %%
df1=data["Sub Product"].fillna("Unknown")

# %%
df2=data["Sub Product"].fillna(data["Sub Product"].mode()[0])

# %%
df3=data["Sub Product"].fillna(method="ffill")

# %%
df4=data['Sub Product'].fillna(method="bfill")

# %% [markdown]
# # filling the data with most convinient method amon the 4 of above

# %%
df['Sub Product'] = df['Sub Product'].astype(str)

# Initialize SimpleImputer with the most frequent strategy
si = SimpleImputer(strategy="most_frequent")

# Apply imputation and assign the transformed data back to the DataFrame
df_imputed = pd.DataFrame(si.fit_transform(df), columns=df.columns)

# %%
nan_row=df_imputed[df_imputed["Sub Product"]=="nan"]
print(nan_row)
# Out:
#     Date Received      Product Name Sub Product  \
# 8      29-07-2013       Credit card         nan
# 19     29-07-2013       Credit card         nan
# 20     29-07-2013  Credit reporting         nan
# 28     29-07-2013  Credit reporting         nan
# 37     29-07-2013       Credit card         nan
# ..            ...               ...         ...
# 815    24-07-2013       Credit card         nan
# 816    25-07-2013  Credit reporting         nan
# 818    24-07-2013  Credit reporting         nan
# 827    01-08-2013  Credit reporting         nan
# 835    25-07-2013  Credit reporting         nan
#
#                                         Issue              Company State Name  \
# 8                           Billing statement             Citibank         OH
# 19                       APR or interest rate  Synchrony Financial         WA
# 20   Credit monitoring or identity protection             Experian         CA
# ...

# %%
df_imputed.isnull().sum()
# Out:
# Date Received                   0
# Product Name                    0
# Sub Product                     0
# Issue                           0
# Company                         0
# State Name                      0
# Zip Code                        0
# Submitted via                   0
# Date Sent to Company            0
# Company Response to Consumer    0
# Timely Response                 0
# Consumer Disputed               0
# Complaint ID                    0
# dtype: int64

# %%
data["Sub Product"]=data["Sub Product"].fillna(data["Sub Product"].mode()[0])

# %%
data[["State Name", "Zip Code"]] = data[["State Name", "Zip Code"]].apply(lambda x: x.fillna(x.mode()[0]), axis=0)

# %%
data.isnull().sum()
# Out:
# Date Received                   0
# Product Name                    0
# Sub Product                     0
# Issue                           0
# Company                         0
# State Name                      0
# Zip Code                        0
# Submitted via                   0
# Date Sent to Company            0
# Company Response to Consumer    0
# Timely Response                 0
# Consumer Disputed               6
# Complaint ID                    0
# dtype: int64

# %%
data.head(9)
# Out:
#   Date Received             Product Name  \
# 0    29-07-2013            Consumer Loan
# 1    29-07-2013  Bank account or service
# 2    29-07-2013  Bank account or service
# 3    29-07-2013  Bank account or service
# 4    29-07-2013                 Mortgage
# 5    29-07-2013  Bank account or service
# 6    29-07-2013          Debt collection
# 7    29-07-2013          Debt collection
# 8    29-07-2013              Credit card
#
#                              Sub Product  \
# 0                           Vehicle loan
# 1                       Checking account
# 2                       Checking account
# 3                       Checking account
# 4            Conventional fixed mortgage
# 5                       Checking account
# 6  Other (i.e. phone, health club, etc.)
# 7                          I do not know
# 8                         Other mortgage
#
#                                       Issue                     Company  \
# ...
