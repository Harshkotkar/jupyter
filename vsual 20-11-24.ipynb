# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
plt.plot(np.random.randn(100).cumsum(),'--')

# %%
#cumulative sum 

list=[1,9,3,4,5]
l=len(list)
cum=[]
a=0
for i in range(0,l):
    a+=list[i]
    cum.append(a)
print(cum)
# Out:
# [1, 10, 13, 17, 22]

# %%
#cumulative sum using user input
user=int(input())
list=[]
for i in range(user):
    e=int(input("enter the numbers:"))
    list.append(e)
a=0
cumulative=[]
for j in range(len(list)):
    a+=list[j]
    cumulative.append(a)
print(cumulative)
for k in range(len(cumulative)):
    print(cumulative[k])
# Out:
# 5
# enter the numbers:1
# enter the numbers:2
# enter the numbers:3
# enter the numbers:4
# enter the numbers:5
# [1, 3, 6, 10, 15]
# 1
# 3
# 6
# 10
# 15
